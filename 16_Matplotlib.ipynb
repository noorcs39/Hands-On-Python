# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9f1dcbdb3c79> in <module>
#       1 import matplotlib
#       2
# ----> 3 print(matplotlib__version__)
#
# NameError: name 'matplotlib__version__' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
xpoint= np.array([1,2,3])
ypoint=np.array([1,2,3])

plt.plot(xpoint,ypoint)

# %%
import matplotlib.pyplot as plt

import numpy as np

xpoints=np.array([1,2,3])
ypoints=np.array([1,2,3])

plt.plot(xpoints,ypoints)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv("Ownexp.csv")

plt.plot(["Area"],["Price"])
